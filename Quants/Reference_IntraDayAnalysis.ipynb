# %%
import os
import pandas as pd
import numpy
import sqlalchemy
import mysql.connector
import sys
import os.path
import math
import shutil
from os import path
from mysql.connector import errorcode
from sqlalchemy import MetaData, create_engine
from sqlalchemy.exc import IntegrityError
from datetime import datetime, timedelta
from sqlalchemy.exc import ResourceClosedError, ProgrammingError

# IEX packages
from iexfinance.refdata import *
from iexfinance.stocks import *
from iexfinance.iexdata import *
from iexfinance.stocks import get_historical_data
from iexfinance.account import get_metadata
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

BASE_DIR = 'C:\\Users\\pshar\\Dropbox\workspace\\HelloPython\\HistoricalMarketData\\ByMinutes'

# %% [markdown]
# ### Next Steps:
# - Divide the dt into date and time and then group entries by date.
# - Keep only the 'Market' entities

# %%
def sqlConnect():
    username = "psharma"
    pwd = "$ys8dmin"
    DB_URL = 'mysql+mysqlconnector://'+username+':'+pwd+'@localhost/markets'
    engine = create_engine(DB_URL)
    connection = engine.connect()
    return connection

# %%
def executeQuery(connection, query):
    dfrm = pd.DataFrame()
    try:
        dfrm = pd.read_sql(query, connection)
    except ProgrammingError as err:
        print(err)
    return dfrm

# %%
symbol = 'BAC'
query = "select * from "+symbol+" order by dt desc"
connection = sqlConnect()
dfrm = executeQuery(connection, query)
dfrm.set_index('dt', inplace=True)
connection.close()  # Finally, close out the SQL connection
# Out:
#       symbol                  dt  average  changeOverTime   close        date  \
# 0        BAC 2020-06-12 15:59:00   24.780       -0.008562  24.775  2020-06-12
# 1        BAC 2020-06-12 15:58:00   24.812       -0.007282  24.825  2020-06-12
# 2        BAC 2020-06-12 15:57:00   24.798       -0.007842  24.800  2020-06-12
# 3        BAC 2020-06-12 15:56:00   24.795       -0.007962  24.815  2020-06-12
# 4        BAC 2020-06-12 15:55:00   24.764       -0.009202  24.790  2020-06-12
# 5        BAC 2020-06-12 15:54:00   24.713       -0.011243  24.715  2020-06-12
# 6        BAC 2020-06-12 15:53:00   24.685       -0.012363  24.695  2020-06-12
# 7        BAC 2020-06-12 15:52:00   24.754       -0.009602  24.745  2020-06-12
# 8        BAC 2020-06-12 15:51:00   24.802       -0.007682  24.800  2020-06-12
# 9        BAC 2020-06-12 15:50:00   24.764       -0.009202  24.765  2020-06-12
# 10       BAC 2020-06-12 15:49:00   24.729       -0.010603  24.735  2020-06-12
# ...

# %%
dfrm.set_index('dt', inplace=True)
dfrm.describe
# Out:
# <bound method NDFrame.describe of                     symbol  average  changeOverTime   close        date  \
# dt
# 2020-06-12 15:59:00    BAC   24.780       -0.008562  24.775  2020-06-12
# 2020-06-12 15:58:00    BAC   24.812       -0.007282  24.825  2020-06-12
# 2020-06-12 15:57:00    BAC   24.798       -0.007842  24.800  2020-06-12
# 2020-06-12 15:56:00    BAC   24.795       -0.007962  24.815  2020-06-12
# 2020-06-12 15:55:00    BAC   24.764       -0.009202  24.790  2020-06-12
# 2020-06-12 15:54:00    BAC   24.713       -0.011243  24.715  2020-06-12
# 2020-06-12 15:53:00    BAC   24.685       -0.012363  24.695  2020-06-12
# 2020-06-12 15:52:00    BAC   24.754       -0.009602  24.745  2020-06-12
# 2020-06-12 15:51:00    BAC   24.802       -0.007682  24.800  2020-06-12
# 2020-06-12 15:50:00    BAC   24.764       -0.009202  24.765  2020-06-12
# 2020-06-12 15:49:00    BAC   24.729       -0.010603  24.735  2020-06-12
# ...

# %% [markdown]
# ### DONE:
# -

# %%
dfrm.columns
# Out:
# Index(['symbol', 'average', 'changeOverTime', 'close', 'date', 'high', 'label',
#        'low', 'marketAverage', 'marketChangeOverTime', 'marketClose',
#        'marketHigh', 'marketLow', 'marketNotional', 'marketNumberOfTrades',
#        'marketOpen', 'marketVolume', 'notional', 'numberOfTrades', 'open',
#        'volume'],
#       dtype='object')

# %%
grouped_symbol = dfrm.groupby('symbol')
for symbol, grouped_date in grouped_symbol:
    print(symbol.lower())
    if symbol.lower() == 'bac':
        print('here')
        # subDfrm = grouped_date.loc[:,('symbol', 'marketHigh', 'marketAverage', 'marketLow', 'marketVolume')]
        subDfrm = grouped_date.loc[:,('symbol', '', 'marketAverage', 'marketVolume')]
        print(subDfrm)
# Out:
# bac
# here
#                     symbol  marketNotional  marketAverage  marketVolume
# dt
# 2020-06-12 15:59:00    BAC     22036875.50         24.787        889064
# 2020-06-12 15:58:00    BAC     24175052.15         24.814        974243
# 2020-06-12 15:57:00    BAC     10604169.96         24.801        427573
# 2020-06-12 15:56:00    BAC     11916386.19         24.796        480586
# 2020-06-12 15:55:00    BAC     11717685.67         24.756        473322
# 2020-06-12 15:54:00    BAC      8086153.07         24.715        327173
# 2020-06-12 15:53:00    BAC     10468898.83         24.693        423958
# 2020-06-12 15:52:00    BAC      9570668.58         24.761        386526
# 2020-06-12 15:51:00    BAC      9096245.88         24.791        366919
# 2020-06-12 15:50:00    BAC     12641030.07         24.762        510490
# 2020-06-12 15:49:00    BAC      8609626.57         24.719        348298
# 2020-06-12 15:48:00    BAC      7513782.26         24.716        304004
# ...
