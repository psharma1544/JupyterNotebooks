# %% [markdown]
# # Sample Purchase Signals based on Technical Indicators
# Author: **Peeyush Sharma**; Feedback: **PSharma3@gmail.com**
#
# This notebook takes the work captured under 'Reference_Plot_Technical_Indicators' notebook forward and lists the stocks that meet the buying criteria listed there. The buying criteria is strictly based on technical indicators. A few of these indicators are aggregated in a single selection criteria and then samples are retrieved for certain durations (bi-weekly, monthly, quarterly etc...). There is no macro analysis here whether at economy, sector, or even longer term growth perspective level for individual company. There is no guarantee that the daily market data or the derived economic indicators are correct. This notebook is for educational and demonstrative purposes only.

# %%
import os
import os.path
from datetime import datetime, timedelta

import pandas as pd

pd.options.mode.chained_assignment = None 
import warnings
from sqlalchemy import create_engine, text
from pandas.errors import EmptyDataError
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
BASE_DIR = '../../../../workspace/HelloPython/HistoricalMarketData/TechnicalIndicators'
DURATIONS = (14, 30, 90, 200) # Roughly for bi-weekly, monthly, quarterly, and 200 days moving averages and other tech indicators

# %%
try:
    DB = os.environ["DB"]
    DB_USER = os.environ["DB_USER"]
    DB_PWD = os.environ["DB_PWD"]
except KeyError:
    raise Exception("Required environment variables DB_USER and DB_PWD not set")
DB_URL = 'mysql+mysqlconnector://' + DB_USER + ':' + DB_PWD + '@localhost/' + DB
ENGINE = create_engine(DB_URL)

# %%
# Retrieve data for Technical Indicators from pre-calculated CSVs
def generate_file_path(symbol, date=None):
    if date is not None:
        str_date = datetime.strftime(date, '%Y%m%d')
        file_name = symbol.lower()+'_'+str_date+'.csv'
        file_path = os.path.join(BASE_DIR, file_name)
    else: 
        file_name = symbol.lower()+'.csv'
        file_path = os.path.join(BASE_DIR, file_name)
    if file_path is None:
            print('Could not find file for symbol:{}'.format(symbol))
    # print(file_path)
    return file_path, file_name

# %%
def retrieve_ticker_close_data(symbol, str_date_from = None, str_date_to = None):
    if str_date_from is None:
        dt_from = datetime(1999, 12, 31)
    else: dt_from = datetime.strptime(str_date_from, '%Y-%m-%d')
    if str_date_to is None:
        dt_to = datetime.now() - timedelta(days=1)
    else: dt_to = datetime.strptime(str_date_to, '%Y-%m-%d')

    file_path, _ = generate_file_path(symbol)
    if file_path is not None:
        try:
            dfrm = pd.read_csv(file_path)
            dfrm['date'] = pd.to_datetime(dfrm['date'])
            dfrm.set_index('date', inplace=True)
            dfrm = dfrm.loc[dt_from: dt_to, :]
            dfrm = dfrm[~dfrm.index.duplicated()]
            return dfrm
        except FileNotFoundError as e:
            print('Exception reading input data for symbol {}.'.format(symbol.upper()))
            print(e)
            return None
        except EmptyDataError as e:
            print(f'No technical indicators found for {symbol.upper()}. Skipping')
    else: return None

# %%
def buying_opps(dfrm, duration):
    """
    Identifies dates for buying opportunities based on different critera. The criteria here
    is hard coded based on earlier experiments - this can be optimized further.
    :param dfrm:
    :param duration:
    :return:
    """
    dates_lows_for_buy_opps = [ date for date in dfrm.index if dfrm.loc[date, 'oscillator_'+str(duration)] < 25 and dfrm.loc[date, 'pcntleVolume_'+str(duration)] > 90 and dfrm.loc[date, 'pcntleStdDevs_'+str(duration)] > 90]
    return dates_lows_for_buy_opps

# %%
# dfrm = retrieve_ticker_close_data('NVDA')
# buying_dates = buying_opps(dfrm, duration)
# print(type(buying_dates))
# print(buying_dates)

# %%
if __name__ == "__main__":
    duration = 90
    symbols_w_buy_opp_dates = dict()
    last_quarter = datetime.now() - timedelta(days=30)

    query = 'select distinct symbol from industrybackground where SnP500 like 1'
    # query = 'select distinct symbol from industrybackground where SnP500 like 1 and symbol not \
    # in (select distinct symbol from equities_historic_data where date like "2019-12-20")'

    with ENGINE.connect() as conn:
        res = conn.execute(text(query))
    dfrm_lst_symbols = pd.DataFrame(res.mappings().all())
    symbols = dfrm_lst_symbols['symbol'].tolist()

    for symbol in symbols:
        dfrm = retrieve_ticker_close_data(symbol)
        if dfrm is None or dfrm.empty:
            print(f'Np data received for symbol {symbol}. Skipping...')
            continue
        buy_dates = buying_opps(dfrm, duration)
        symbols_w_buy_opp_dates[symbol] = buy_dates

    for symbol, dates in symbols_w_buy_opp_dates.items():
        dates_recent = [date.date() for date in dates if date > last_quarter]
        if len(dates_recent) > 0:
            print(f'{symbol.upper()} has had buying opp in the last month on the following dates: ({dates_recent})')
# Out:
# A has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# AAL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# AAP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# AAPL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# ACN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# ADI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# ADP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8)])
# ADSK has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# AIV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# ALB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 15), datetime.date(2025, 4, 16)])
# ALGN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 9)])
# ALK has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 16), datetime.date(2025, 4, 24), datetime.date(2025, 4, 25), datetime.date(2025, 4, 28)])
# ALL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# AMAT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# AME has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# AMG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# AMP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# AMZN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# ANET has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# ANSS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# APA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# APD has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 16), datetime.date(2025, 4, 17)])
# APH has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# APTV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 14)])
# ARE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 29)])
# AVB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# AXP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# AYI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 16)])
# BAC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# BBY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# BDX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 15), datetime.date(2025, 4, 17), datetime.date(2025, 4, 23)])
# BIO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 14)])
# BLK has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# BMY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15), datetime.date(2025, 4, 16), datetime.date(2025, 4, 23), datetime.date(2025, 4, 24), datetime.date(2025, 4, 28), datetime.date(2025, 4, 29)])
# BWA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# C has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# CAT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# CBRE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 21), datetime.date(2025, 4, 23)])
# CCL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15)])
# CDNS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# CDW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# CF has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 16)])
# CFG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15), datetime.date(2025, 4, 16)])
# CHD has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 23), datetime.date(2025, 4, 24), datetime.date(2025, 4, 25), datetime.date(2025, 4, 28), datetime.date(2025, 4, 30)])
# CHRW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9)])
# CLX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 14)])
# CMA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17), datetime.date(2025, 4, 21), datetime.date(2025, 4, 22)])
# CMI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 21), datetime.date(2025, 4, 22), datetime.date(2025, 4, 29)])
# COF has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 21)])
# COP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10)])
# COTY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15)])
# CRM has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 16), datetime.date(2025, 4, 21)])
# CSCO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# CSX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 16), datetime.date(2025, 4, 21)])
# CTSH has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# CVX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# DAL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# DFS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# DHR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# DIS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 17)])
# DLR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# DOV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17)])
# DOW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 11), datetime.date(2025, 4, 15), datetime.date(2025, 4, 24)])
# DVA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 16), datetime.date(2025, 4, 21)])
# DXC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# DXCM has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# EFX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17), datetime.date(2025, 4, 21)])
# EL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 17)])
# EMN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 15), datetime.date(2025, 4, 25)])
# EMR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 23)])
# EOG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 17)])
# ESS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# ETN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# EXPE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# FANG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# FDX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# FITB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 17)])
# FL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 28)])
# FLR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 11)])
# FLS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 21), datetime.date(2025, 4, 22), datetime.date(2025, 4, 23)])
# FRT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# FTI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 16), datetime.date(2025, 4, 23)])
# FTV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 5, 1)])
# GLW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# GOOG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# GOOGL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# GPN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 16), datetime.date(2025, 4, 17), datetime.date(2025, 4, 21), datetime.date(2025, 4, 22), datetime.date(2025, 4, 24)])
# GRMN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 30)])
# GS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# HAL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 22), datetime.date(2025, 4, 23)])
# HAS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 23)])
# HBAN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 9)])
# HBI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# HD has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# HES has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 24), datetime.date(2025, 4, 30)])
# HLT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# HON has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8)])
# HP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# HPE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15)])
# HPQ has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# HST has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# IDXX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# IEX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17), datetime.date(2025, 4, 23)])
# ILMN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# INCY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9)])
# INFO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# IPG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 16)])
# IQV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 17)])
# IR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# IRM has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# ISRG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 10)])
# IT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# ITW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# IVZ has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 22)])
# JBHT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 9), datetime.date(2025, 4, 11), datetime.date(2025, 4, 16), datetime.date(2025, 4, 17), datetime.date(2025, 4, 23), datetime.date(2025, 4, 25)])
# JCI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# JKHY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# JNPR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8)])
# JPM has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# KEY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# KEYS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# KMX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# KSS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 21)])
# L has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# LEG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# LH has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 11)])
# LLY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# LOW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# LRCX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# LUV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 23), datetime.date(2025, 4, 24)])
# LVS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 22), datetime.date(2025, 4, 23)])
# LYB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10)])
# LYV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# M has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 24)])
# MA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# MAA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# MAC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# MAR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 23)])
# MAS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 21), datetime.date(2025, 4, 22), datetime.date(2025, 4, 23)])
# MAT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# MCO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17), datetime.date(2025, 4, 21)])
# MET has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# MGM has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# MKC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# MPC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# MRK has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 11), datetime.date(2025, 4, 16), datetime.date(2025, 4, 17)])
# MS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# MSCI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 21)])
# MSFT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# MSI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# MTB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 21)])
# MTD has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 23), datetime.date(2025, 4, 24)])
# MU has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# NCLH has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# NDAQ has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# NKE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# NOV has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 28), datetime.date(2025, 4, 29), datetime.date(2025, 4, 30)])
# NOW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# NSC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 21)])
# NTAP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# NTRS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 10), datetime.date(2025, 4, 22)])
# NVDA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# NWL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# NWSA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# ODFL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 23), datetime.date(2025, 4, 25)])
# OKE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# ORCL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# OXY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# PCAR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 29)])
# PFE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# PFG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 25)])
# PH has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# PKG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# PLD has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# PNC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15)])
# PNR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 21)])
# PPG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# PRGO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8)])
# PRU has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# PSX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# PYPL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 9)])
# QCOM has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# RCL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# REG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# RF has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17)])
# RHI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 17)])
# RJF has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 17)])
# RL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# RMD has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15), datetime.date(2025, 4, 23)])
# ROK has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17)])
# RRC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 24)])
# SBUX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 30)])
# SEE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# SLB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10)])
# SNA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 21)])
# SNPS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# SPG has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# SPGI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 21)])
# SRE has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# STT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 17), datetime.date(2025, 4, 21)])
# STX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# SWK has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 30)])
# SWKS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# SYF has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 21), datetime.date(2025, 4, 22)])
# SYK has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# TDY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 23)])
# TEL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# TFX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# TGT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# TMO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 17), datetime.date(2025, 4, 22), datetime.date(2025, 4, 23), datetime.date(2025, 4, 24)])
# TROW has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 17)])
# TSCO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 24)])
# TXN has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 23)])
# TXT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 21)])
# TYL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 24), datetime.date(2025, 4, 25), datetime.date(2025, 4, 28), datetime.date(2025, 4, 29), datetime.date(2025, 4, 30)])
# UAA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15)])
# UAL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 16)])
# UDR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# UNH has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 25), datetime.date(2025, 4, 29)])
# UNP has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 16), datetime.date(2025, 4, 24)])
# UPS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# URI has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 22)])
# USB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# VFC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# VLO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 24)])
# VMC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# VNO has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8)])
# WAB has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10)])
# WAT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11)])
# WDC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# WFC has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14)])
# WHR has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# WMT has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7)])
# WST has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 10)])
# WU has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 21)])
# WY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 16), datetime.date(2025, 4, 24), datetime.date(2025, 4, 25), datetime.date(2025, 4, 28), datetime.date(2025, 4, 29)])
# XRAY has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9)])
# XRX has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9)])
# XYL has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 10), datetime.date(2025, 4, 16)])
# ZBH has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 11), datetime.date(2025, 4, 14), datetime.date(2025, 4, 15), datetime.date(2025, 4, 17)])
# ZBRA has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 9)])
# ZION has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 7), datetime.date(2025, 4, 8), datetime.date(2025, 4, 9), datetime.date(2025, 4, 21), datetime.date(2025, 4, 22)])
# ZTS has had buying opp in the last month on the following dates: ([datetime.date(2025, 4, 10), datetime.date(2025, 4, 17)])
